# %%
import numpy as np
import matplotlib.pyplot as plt
from OCP_algorithms import hospital_capacity_objective_solve, quadratic_objective_solve, week_objective_solve

from SIR_Plotting_Routines import *
import pysindy as ps
import glob
import pandas as pd


from os.path import basename
import os
import sys


cwd = os.path.dirname(os.path.abspath(''))
# sys.path.append(cwd + '/Cpp/build/Binders/')
import pyFROLS as pf

DATA_DIR = cwd + '/Cpp/data/'
FIGURE_DIR = cwd + '/../../figures/'

# %%
N_pop = 100
p_ER = 1
d_max = 1
N_output_max = 80
Nx = 3
Nu = 1
Nt = 50
er_model = pf.Polynomial_Model(Nx,Nu,N_output_max,d_max)
er_features = er_model.read_csv(DATA_DIR + 'ERR_Simulation_SIR_' + str(N_pop) + '_' + str(p_ER) + '/param.csv')

# %%
qr_model = pf.Polynomial_Model(Nx,Nu,N_output_max,d_max)
qr_features = qr_model.read_csv(DATA_DIR + 'Quantile_Simulation_SIR_' + str(N_pop) + '_' + str(p_ER) + '/param.csv')

# %%
from pysindy_casadi_converter import construct_mx_equations
import casadi as cs

# %%
DATA_DIR
# Out:
# '/home/man/Documents/Bernoulli_MC/Cpp/data/'

# %%
def load_SIR_trajectories():
    trajs = glob.glob(DATA_DIR + 'ERR_Simulation_SIR_' + str(N_pop) + '_' + str(p_ER) + '/trajectory*.csv')
    dfs = [pd.read_csv(traj) for traj in trajs[:100] if "Quantile" not in traj]
    
    # print(dfs[0].columns)
    N_traj = len(dfs)
    X = [df[['S', 'I', 'R']].to_numpy() for df in dfs]
    U = [df['p_I'].to_numpy() for df in dfs]

    return X, U

X_sim, U_sim = load_SIR_trajectories()
#get mean of all X_sim
X_mean = np.mean(np.array(X_sim), axis=0)
U_mean = np.mean(np.array(U_sim), axis=0)

# %%
import random
N_sims = 100
p_I0 = 0.1
# #generate integer seeds
# qr_seeds = [random.randint(0, 1000000) for i in range(N_sims)]

# er_sims = pf.Bernoulli_SIR_MC_Simulations(N_pop, p_ER, p_I0, er_seeds, Nt, 100)
# qr_sims = pf.Bernoulli_SIR_MC_Simulations(N_pop, p_ER, p_I0, qr_seeds, Nt, 100)
# er_X_list = [np.array([x[0], x[1], x[2]]) for x in er_sims]
# qr_X_list = [np.array([x[0], x[1], x[2]]) for x in qr_sims]
graph_seed = 777
G_structure = pf.generate_SIR_ER_graph(N_pop, p_ER, graph_seed)
G = pf.generate_Bernoulli_SIR_Network(G_structure, p_I0, graph_seed, 0)
# Out:
# size: 32

# %%
G.reset()
G.initialize()
p_gen = pf.MC_SIR_Params()
p_gen.N_pop = 100
p_gen.p_ER = 1
p_gen.p_I0 = 0.1
er_param = pf.Regressor_Param()
er_param.tol = 1e-4
er_regressor = pf.ERR_Regressor(er_param)


er_seeds = [random.randint(0, 1000000) for i in range(N_sims)]

# %%
Nc = 10
Wu = 1
x  = cs.MX.sym('x', Nx)
u  = cs.MX.sym('u', Nu)

p_step = pf.SIR_Param()
p_step.p_R = 0.1

G.reset()
G.initialize()
er_x_preds = []
er_us = []
rds = []
er_true_traj = np.zeros((Nx, (Nc)*7 + 1))
er_true_traj[:,0] = G.population_count()
er_true_u = np.zeros(((Nc)*7))
for i in range(Nc):
    rd = pf.MC_SIR_simulations_to_regression(G_structure, p_gen, er_seeds, Nt)
    rds.append(rd)
    features = [er_regressor.transform_fit(rd.X, rd.U, rd.Y[:, i:i+1], er_model) for i in range(rd.Y.shape[1])]
    er_X_mean = np.mean(np.reshape(rd.X, (N_sims, Nt, Nx)), axis=0)
    er_U_mean = np.mean(np.reshape(rd.U, (N_sims, Nt, Nu)), axis=0)
    er_model.feature_summary(features)
    F_ODE = cs.Function("F_ODE_" + str(i), [x, u], [cs.vertcat(*construct_mx_equations(x, u, er_model, features))])
    er_sol, er_x_pred, er_u = week_objective_solve(er_X_mean, er_U_mean, Wu, F_ODE, Nt, N_pop)
    er_x_preds.append(er_x_pred)
    er_us.append(er_u)
    p_step.p_I = er_u[0]
    for j in range(7):
        G.advance(p_step)
        er_true_traj[:,i*7+j+1] = G.population_count()
        er_true_u[i*7+j] = p_step.p_I
    # p_gen.p_I_max = 2*np.max(er_u)
# Out:
#        y           Feature           g            Theta          f_ERR           Tag
#        0             x0            0.983          1.002          0.999       REGRESSION          4
#        0           x0x1u0         -0.229         -0.292          0.001       REGRESSION         13
#        0          x0x1x2u0         0.006          0.006          0.000       REGRESSION         15
#        0            x0u0          -1.787         -1.787          0.000       REGRESSION          8
#        1             x1            0.990          0.928          0.983       REGRESSION          3
#        1           x0x1u0          0.330          0.248          0.006       REGRESSION         13
#        1          x0x1x2u0        -0.007         -0.007          0.001       REGRESSION         15
#        1            x0u0           1.358          1.358          0.000       REGRESSION          8
#        2             x2            1.017          0.999          0.999       REGRESSION          2
#        2             x1            0.106          0.090          0.001       REGRESSION          3
#        2            x0u0           0.502          0.297          0.000       REGRESSION          8
#        2           x0x1u0          0.023          0.023          0.000       REGRESSION         13
#
# ******************************************************************************
# This program contains Ipopt, a library for large-scale nonlinear optimization.
#  Ipopt is released as open source code under the Eclipse Public License (EPL).
#          For more information visit https://github.com/coin-or/Ipopt
# ******************************************************************************
#
# This is Ipopt version 3.14.4, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       36
#
# Total number of variables............................:        8
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.2890294e+03 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  3.5506820e+03 0.00e+00 1.00e+02  -1.0 1.13e-02   4.0 1.00e+00 1.00e+00f  1
#    2  1.1243792e+03 0.00e+00 4.92e+01  -1.0 1.06e-01    -  1.36e-01 7.84e-01f  1
#    3  6.4176828e+02 0.00e+00 1.61e+01  -1.0 6.55e-02    -  5.12e-01 7.19e-01f  1
#    4  5.7949680e+02 0.00e+00 1.90e+01  -1.0 4.56e-02    -  1.00e+00 1.00e+00f  1
#    5  5.5979248e+02 0.00e+00 2.86e+01  -1.0 6.44e-03   3.5 1.00e+00 1.00e+00f  1
#    6  5.0480359e+02 0.00e+00 8.70e+00  -1.0 1.24e-01   3.0 5.21e-01 2.60e-01f  1
#    7  5.0771105e+02 0.00e+00 6.20e+00  -1.0 1.13e-02    -  8.66e-01 1.00e+00f  1
#    8  5.0837574e+02 0.00e+00 2.02e-02  -1.0 1.49e-03    -  1.00e+00 1.00e+00f  1
#    9  4.7895208e+02 0.00e+00 5.15e-01  -2.5 8.38e-03    -  9.23e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 12
# Total seconds in IPOPT                               = 0.007
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 947.00us ( 72.85us) 940.78us ( 72.37us)        13
#   nlp_grad_f  |   1.03ms ( 73.86us)   1.04ms ( 74.15us)        14
#   nlp_hess_l  | 166.00us ( 13.83us) 165.83us ( 13.82us)        12
#        total  |   7.03ms (  7.03ms)   7.04ms (  7.04ms)         1
#        y           Feature           g            Theta          f_ERR           Tag
# This is Ipopt version 3.14.4, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:       36
#
# Total number of variables............................:        8
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.2308726e+03 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  4.5901040e+01 0.00e+00 2.21e-01  -1.0 9.07e-02    -  1.00e+00 9.98e-01f  1
#    2  7.0628675e+01 0.00e+00 7.11e-15  -1.7 6.60e-03    -  1.00e+00 1.00e+00f  1
#    3  5.2672549e+01 0.00e+00 7.99e-15  -2.5 3.78e-03    -  1.00e+00 1.00e+00f  1
#    4  4.7227150e+01 0.00e+00 7.55e-15  -3.8 3.02e-03    -  1.00e+00 1.00e+00f  1
#    5  4.5842412e+01 0.00e+00 7.11e-15  -3.8 1.46e-03    -  1.00e+00 1.00e+00f  1
#    6  4.5449741e+01 0.00e+00 6.00e-15  -5.7 8.72e-04    -  1.00e+00 1.00e+00f  1
#    7  4.5347530e+01 0.00e+00 6.66e-15  -5.7 4.35e-04    -  1.00e+00 1.00e+00f  1
#    8  4.5320155e+01 0.00e+00 7.30e-15  -5.7 2.11e-04    -  1.00e+00 1.00e+00f  1
#    9  4.5311852e+01 0.00e+00 6.98e-15  -8.6 1.19e-04    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  4.5309441e+01 0.00e+00 7.17e-15  -8.6 5.93e-05    -  1.00e+00 1.00e+00f  1
#   11  4.5308837e+01 0.00e+00 7.48e-15  -8.6 2.95e-05    -  1.00e+00 1.00e+00f  1
#   12  4.5308756e+01 0.00e+00 7.52e-15  -8.6 1.45e-05    -  1.00e+00 1.00e+00f  1
#        0              1            4.000          4.000          1.000       REGRESSION          0
#        1             x1            0.902          0.805          0.979       REGRESSION          3
#        1            x1x2           0.001          0.001          0.000       REGRESSION          7
#        1             u0           -0.584         -0.773          0.000       REGRESSION          1
#        1              1            0.003          0.003          0.000       REGRESSION          0
#        2             x2            1.002          1.002          1.000       REGRESSION          2
#   13  4.5308750e+01 0.00e+00 7.22e-15  -8.6 6.77e-06    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 13
#
#                                    (scaled)                 (unscaled)
# Objective...............:   3.5366635233059945e-01    4.5308750165333301e+01
# Dual infeasibility......:   7.2164496600635175e-15    9.2451066541631193e-13
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   9.6613306499678491e-09    1.2377281972102288e-06
# Overall NLP error.......:   9.6613306499678491e-09    1.2377281972102288e-06
#
#
# Number of objective function evaluations             = 14
# Number of objective gradient evaluations             = 14
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 13
# Total seconds in IPOPT                               = 0.017
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   1.05ms ( 74.86us)   1.04ms ( 74.13us)        14
#   nlp_grad_f  |   1.91ms (127.60us)   1.94ms (129.60us)        15
#   nlp_hess_l  |   8.31ms (639.31us)   8.31ms (639.46us)        13
#        total  |  16.88ms ( 16.88ms)  16.88ms ( 16.88ms)         1
#        y           Feature           g            Theta          f_ERR           Tag
#        0              1            4.000          4.000          1.000       REGRESSION          0
#        1             x1            0.900          0.556          0.958       REGRESSION          3
#        1            x1x2           0.004          0.004          0.000       REGRESSION          7
#        1             u0           -0.218         -0.376          0.000       REGRESSION          1
#        1              1            0.002          0.002          0.000       REGRESSION          0
#        2             x2            1.001          1.001          1.000       REGRESSION          2
# This is Ipopt version 3.14.4, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:
#   34  5.1582694e+02 0.00e+00 5.71e-04  -5.7 3.68e-05    -  1.00e+00 1.00e+00f  1
#   35  5.1582691e+02 0.00e+00 6.66e-06  -5.7 5.71e-06    -  1.00e+00 1.00e+00f  1
#   36  5.1582672e+02 0.00e+00 1.23e-03  -8.6 5.26e-05    -  1.00e+00 1.00e+00f  1
#   37  5.1582671e+02 0.00e+00 7.19e-05  -8.6 2.31e-05    -  1.00e+00 1.00e+00f  1
#   38  5.1582671e+02 0.00e+00 1.00e-06  -8.6 7.21e-06    -  1.00e+00 1.00e+00f  1
#   39  5.1582671e+02 0.00e+00 8.97e-09  -8.6 8.76e-07    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 39
#
#                                    (scaled)                 (unscaled)
# Objective...............:   4.0288022161783186e+00    5.1582670594620163e+02
# Dual infeasibility......:   8.9660733921976247e-09    1.1479690128735977e-06
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.6256459499018094e-09    3.3617393672990619e-07
# Overall NLP error.......:   8.9660733921976247e-09    1.1479690128735977e-06
#
#
# Number of objective function evaluations             = 134
# Number of objective gradient evaluations             = 40
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 39
# Total seconds in IPOPT                               = 0.088
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   9.91ms ( 73.98us)   9.89ms ( 73.83us)       134
#   nlp_grad_f  |   6.77ms (165.10us)   6.76ms (164.94us)        41
#   nlp_hess_l  |  50.41ms (  1.29ms)  50.55ms (  1.30ms)        39
#        total  |  88.47ms ( 88.47ms)  88.47ms ( 88.47ms)         1
# [Regressor] Warning: threshold is too high for candidates
#        y           Feature           g            Theta          f_ERR           Tag
#        0             x2            0.042          0.042          1.000       REGRESSION          2
#        2              1           96.000         96.000          1.000       REGRESSION          0
# This is Ipopt version 3.14.4, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:        0
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        8
#
# Total number of variables............................:        8
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        8
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:        0
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  4.1796013e+03 0.00e+00 1.00e+02  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  5.2158177e-01 0.00e+00 1.50e-01  -1.0 9.07e-02    -  1.00e+00 9.98e-01f  1
#    2  1.2761253e+00 0.00e+00 2.00e-15  -2.5 6.10e-04    -  1.00e+00 1.00e+00f  1
#    3  3.6636588e-01 0.00e+00 7.66e-15  -3.8 1.68e-03    -  1.00e+00 1.00e+00f  1
#    4  9.2207661e-02 0.00e+00 6.05e-15  -5.7 1.01e-03    -  1.00e+00 1.00e+00f  1
#    5  2.3524518e-02 0.00e+00 9.58e-16  -5.7 5.06e-04    -  1.00e+00 1.00e+00f  1
#    6  6.3620022e-03 0.00e+00 3.84e-15  -5.7 2.47e-04    -  1.00e+00 1.00e+00f  1
#    7  1.5913083e-03 0.00e+00 4.88e-07  -8.6 1.35e-04    -  1.00e+00 1.00e+00f  1
#    8  3.9840268e-04 0.00e+00 1.24e-15  -8.6 6.75e-05    -  1.00e+00 1.00e+00f  1
#    9  1.0020834e-04 0.00e+00 2.06e-15  -8.6 3.37e-05    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.5679891e-05 0.00e+00 1.80e-15  -8.6 1.67e-05    -  1.00e+00 1.00e+00f  1
#   11  7.0678427e-06 0.00e+00 1.17e-15  -8.6 8.13e-06    -  1.00e+00 1.00e+00f  1
#   12  2.0021483e-06 0.00e+00 7.53e-15  -9.0 4.21e-06    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5641766004021226e-08    2.0021483194178002e-06
# Dual infeasibility......:   7.5295672474773312e-15    9.6378570083483225e-13
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   3.9654486598344539e-09    5.0757800417063104e-07
# Overall NLP error.......:   3.9654486598344539e-09    5.0757800417063104e-07
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 12
# Total seconds in IPOPT                               = 0.006
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |
-05    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.5679891e-05 0.00e+00 1.80e-15  -8.6 1.67e-05    -  1.00e+00 1.00e+00f  1
#   11  7.0678427e-06 0.00e+00 1.17e-15  -8.6 8.13e-06    -  1.00e+00 1.00e+00f  1
#   12  2.0021483e-06 0.00e+00 7.53e-15  -9.0 4.21e-06    -  1.00e+00 1.00e+00f  1
#
# Number of Iterations....: 12
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.5641766004021226e-08    2.0021483194178002e-06
# Dual infeasibility......:   7.5295672474773312e-15    9.6378570083483225e-13
# Constraint violation....:   0.0000000000000000e+00    0.0000000000000000e+00
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   3.9654486598344539e-09    5.0757800417063104e-07
# Overall NLP error.......:   3.9654486598344539e-09    5.0757800417063104e-07
#
#
# Number of objective function evaluations             = 13
# Number of objective gradient evaluations             = 13
# Number of equality constraint evaluations            = 0
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 0
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 12
# Total seconds in IPOPT                               = 0.006
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  | 688.00us ( 52.92us) 676.00us ( 52.00us)        13
#   nlp_grad_f  | 782.00us ( 55.86us) 794.88us ( 56.78us)        14
#   nlp_hess_l  | 161.00us ( 13.42us) 157.17us ( 13.10us)        12
#        total  |   6.68ms (  6.68ms)   6.67ms (  6.67ms)         1

# %%
fig, ax = plt.subplots(4)
alphas = np.linspace(0.2, 1, Nc)
t_offset = 0
fake_scale = 1000
for (alpha, rd, er_x_pred, er_u) in zip(alphas, rds, er_x_preds, er_us):
    t = np.array(range(t_offset, t_offset + Nt))
    t_offset += 7
    plot_sim_comparison_SIR(ax, rd, er_x_pred, er_u, t, N_sims, alpha_multiplier=alpha, scale=fake_scale)
t_full = np.array(range(0, er_true_traj.shape[1]))
control_points = np.array(range(0, er_true_traj.shape[1], 7))
#scatter at control points
ax[-1].plot(t_full[:-1], er_true_u, color='black')
_ = [ax[i].scatter(control_points, er_true_traj[i, control_points]*fake_scale, color='black', marker='x', s=10) for i in range(Nx)]
ax[-1].scatter(control_points[:-1], er_true_u[control_points[:-1]], color='black', marker='x', s=10)
_ = [x.plot(t_full, xi*fake_scale, color='black') for x, xi in zip(ax[:-1], er_true_traj)]
ax[-1].set_xlabel('Days')
_ = [x.grid() for x in ax]

# %%
fig, ax = plt.subplots(2)
alphas = np.linspace(0.2, 1, Nc)
t_offset = 0
for (alpha, rd, er_x_pred, er_u) in zip(alphas, rds, er_x_preds, er_us):
    t = np.array(range(t_offset, t_offset + Nt))
    t_offset += 7
    plot_sim_comparison_SIR(ax, rd, er_x_pred, er_u, t, N_sims, alpha_multiplier=alpha, scale=fake_scale, plot_idx=[1])
t_full = np.array(range(0, er_true_traj.shape[1]))
control_points = np.array(range(0, er_true_traj.shape[1], 7))
#scatter at control points
ax[-1].plot(t_full[:-1], er_true_u, color='black')
ax[0].scatter(control_points, er_true_traj[1, control_points]*fake_scale, color='black', marker='x', s=10)
ax[-1].scatter(control_points[:-1], er_true_u[control_points[:-1]], color='black', marker='x', s=10)
ax[0].plot(t_full, er_true_traj[1,:]*fake_scale, color='black')
ax[-1].set_xlabel('Days')
_ = [x.grid() for x in ax]
